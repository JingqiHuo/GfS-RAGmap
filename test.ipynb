# %%
from Google_call import ApiMaps
import folium
import pprint

origin = "55.9533,-3.1883"        # Edinburgh
destination = "56.5142,-2.8189"
api_key = 'AIzaSyBSKwnMJM1n1qGa0i1SG7G7M3cMqhB6Kqg'

map = ApiMaps(api_key)
geojson_route = map.draw_polyline(origin,destination)
# print GeoJSON 

pprint.pprint(geojson_route)

# 地图中心取起点
m = folium.Map(location=[origin], zoom_start=10)

# 添加路线
folium.GeoJson(geojson_route, name="Route").add_to(m)
m
# Out:
# {'geometry': {'coordinates': [[-3.18849, 55.95342],
#                               [-3.18763, 55.95433],
#                               [-3.18688, 55.95562],
#                               [-3.18743, 55.95653],
#                               [-3.18928, 55.95802],
#                               [-3.19112, 55.95926],
#                               [-3.19214, 55.96029],
#                               [-3.1953, 55.9618],
#                               [-3.19677, 55.96238],
#                               [-3.19852, 55.9625],
#                               [-3.19964, 55.96265],
#                               [-3.20135, 55.96366],
#                               [-3.20393, 55.96594],
#                               [-3.20869, 55.97088],
#                               [-3.20936, 55.9712],
#                               [-3.21263, 55.9709],
#                               [-3.21838, 55.97027],
#                               [-3.23099, 55.96901],
#                               [-3.23633, 55.9682],
#                               [-3.23757, 55.96705],
#                               [-3.23785, 55.96594],
#                               [-3.2386, 55.9638],
#                               [-3.24033, 55.96239],
#                               [-3.24436, 55.96117],
#                               [-3.25044, 55.96062],
#                               [-3.25865, 55.96088],
#                               [-3.26768, 55.96213],
#                               [-3.27357, 55.96264],
#                               [-3.2789, 55.96246],
#                               [-3.29357, 55.96075],
#                               [-3.29843, 55.96031],
#                               [-3.30396, 55.9606],
#                               [-3.31206, 55.96135],
#                               [-3.31456, 55.96278],
#                               [-3.31808, 55.96541],
#                               [-3.32267, 55.96817],
#                               [-3.33261, 55.97317],
#                               [-3.3395, 55.97622],
#                               [-3.3438, 55.97825],
#                               [-3.34679, 55.97912],
#                               [-3.35056, 55.97958],
#                               [-3.36019, 55.97971],
#                               [-3.37278, 55.97951],
#                               [-3.37805, 55.97918],
#                               [-3.38213, 55.9782],
#                               [-3.38696, 55.97836],
#                               [-3.39467, 55.97905],
#                               [-3.40137, 55.98026],
#                               [-3.40747, 55.98066],
#                               [-3.41367, 55.98076],
#                               [-3.41687, 55.98139],
#                               [-3.41913, 55.98231],
#                               [-3.42092, 55.98345],
#                               [-3.42249, 55.98524],
#                               [-3.42291, 55.98632],
#                               [-3.42283, 55.98829],
#                               [-3.42042, 55.99264],
#                               [-3.41862, 55.99542],
#                               [-3.4158, 55.99995],
#                               [-3.41075, 56.00792],
#                               [-3.40587, 56.0157],
#                               [-3.40562, 56.01854],
#                               [-3.40658, 56.02042],
#                               [-3.40821, 56.02284],
#                               [-3.40843, 56.02423],
#                               [-3.40813, 56.02623],
#                               [-3.40821, 56.02985],
#                               [-3.40897, 56.03432],
#                               [-3.40825, 56.03653],
#                               [-3.40653, 56.04039],
#                               [-3.4053, 56.04339],
#                               [-3.40385, 56.04482],
#                               [-3.40087, 56.04627],
#                               [-3.39397, 56.04882],
#                               [-3.39158, 56.05002],
#                               [-3.38944, 56.0517],
#                               [-3.38787, 56.05407],
#                               [-3.38735, 56.06196],
#                               [-3.38749, 56.06849],
#                               [-3.38861, 56.07169],
#                               [-3.38969, 56.07364],
#                               [-3.39119, 56.07567],
#                               [-3.39562, 56.07981],
#                               [-3.39965, 56.08286],
#                               [-3.4018, 56.08552],
#                               [-3.40253, 56.0884],
#                               [-3.40222, 56.09012],
#                               [-3.40047, 56.09284],
#                               [-3.39478, 56.0974],
#                               [-3.39187, 56.09963],
#                               [-3.38955, 56.10243],
#                               [-3.38888, 56.10451],
#                               [-3.38894, 56.10629],
#                               [-3.38947, 56.1078],
#                               [-3.39301, 56.1129],
#                               [-3.39383, 56.11473],
#                               [-3.394, 56.11648],
#                               [-3.39328, 56.11914],
#                               [-3.39186, 56.12263],
#                               [-3.39154, 56.1246],
#                               [-3.3918, 56.12606],
#                               [-3.3943, 56.12992],
#                               [-3.39718, 56.13379],
#                               [-3.39747, 56.13445],
#                               [-3.3979, 56.13735],
#                               [-3.3973, 56.1396],
#                               [-3.39592, 56.14171],
#                               [-3.3935, 56.14511],
#                               [-3.39301, 56.14723],
#                               [-3.39313, 56.14865],
#                               [-3.39397, 56.15062],
#                               [-3.39552, 56.15245],
#                               [-3.40035, 56.15721],
#                               [-3.40259, 56.16119],
#                               [-3.4042, 56.16707],
#                               [-3.40676, 56.1714],
#                               [-3.41037, 56.17544],
#                               [-3.41602, 56.18302],
#                               [-3.41932, 56.18891],
#                               [-3.42113, 56.19225],
#                               [-3.42275, 56.19432],
#                               [-3.42638, 56.1977],
#                               [-3.43289, 56.20319],
#                               [-3.4355, 56.20672],
#                               [-3.4371, 56.21038],
#                               [-3.43773, 56.21476],
#                               [-3.43682, 56.21963],
#                               [-3.43523, 56.22286],
#                               [-3.43395, 56.22468],
#                               [-3.43175, 56.22698],
#                               [-3.4289, 56.22885],
#                               [-3.42488, 56.2305],
#                               [-3.41962, 56.23166],
#                               [-3.41386, 56.23198],
#                               [-3.4094, 56.23215],
#                               [-3.40388, 56.23313],
#                               [-3.39857, 56.23515],
#                               [-3.3947, 56.23741],
#                               [-3.38428, 56.24366],
#                               [-3.38131, 56.24596],
#                               [-3.37918, 56.2483],
#                               [-3.37744, 56.25163],
#                               [-3.37694, 56.2547],
#                               [-3.37739, 56.25807],
#                               [-3.37857, 56.26129],
#                               [-3.38182, 56.26605],
#                               [-3.38418, 56.26835],
#                               [-3.3874, 56.27015],
#                               [-3.39305, 56.27241],
#                               [-3.3964, 56.27469],
#                               [-3.39774, 56.27698],
#                               [-3.39781, 56.27876],
#                               [-3.39731, 56.28096],
#                               [-3.39568, 56.28529],
#                               [-3.39328, 56.28789],
#                               [-3.38982, 56.29025],
#                               [-3.3871, 56.29268],
#                               [-3.38545, 56.29511],
#                               [-3.38467, 56.29752],
#                               [-3.38492, 56.30074],
#                               [-3.38594, 56.30367],
#                               [-3.38588, 56.30551],
#                               [-3.38417, 56.30804],
#                               [-3.37929, 56.31063],
#                               [-3.37376, 56.31286],
#                               [-3.37225, 56.31431],
#                               [-3.37188, 56.31577],
#                               [-3.3723, 56.31694],
#                               [-3.37318, 56.31792],
#                               [-3.37532, 56.31905],
#                               [-3.37974, 56.31979],
#                               [-3.38712, 56.32036],
#                               [-3.39305, 56.32204],
#                               [-3.39595, 56.32371],
#                               [-3.39746, 56.32536],
#                               [-3.39962, 56.32932],
#                               [-3.40013, 56.33261],
#                               [-3.39976, 56.33535],
#                               [-3.39875, 56.33814],
#                               [-3.39774, 56.34123],
#                               [-3.39685, 56.34623],
#                               [-3.3974, 56.3501],
#                               [-3.39964, 56.35356],
#                               [-3.40381, 56.35736],
#                               [-3.40852, 56.36004],
#                               [-3.4134, 56.36191],
#                               [-3.41807, 56.36315],
#                               [-3.42112, 56.36435],
#                               [-3.42249, 56.36543],
#                               [-3.42317, 56.36659],
#                               [-3.42339, 56.36819],
#                               [-3.42217, 56.37073],
#                               [-3.41899, 56.37287],
#                               [-3.4148, 56.37437],
#                               [-3.4125, 56.37553],
#                               [-3.41048, 56.37758],
#                               [-3.40607, 56.38329],
#                               [-3.4036, 56.38535],
#                               [-3.39911, 56.3865],
#                               [-3.38705, 56.38672],
#                               [-3.38223, 56.38616],
#                               [-3.37758, 56.38489],
#                               [-3.37268, 56.38325],
#                               [-3.36743, 56.38278],
#                               [-3.35817, 56.38258],
#                               [-3.35248, 56.38218],
#                               [-3.34566, 56.37966],
#                               [-3.34118, 56.37765],
#                               [-3.33507, 56.37488],
#                               [-3.33111, 56.37397],
#                               [-3.32496, 56.37381],
#                               [-3.31979, 56.37401],
#                               [-3.31419, 56.37457],
#                               [-3.30861, 56.37618],
#                               [-3.29992, 56.38071],
#                               [-3.29121, 56.38466],
#                               [-3.27741, 56.39061],
#                               [-3.27409, 56.39316],
#                               [-3.27179, 56.39558],
#                               [-3.26855, 56.39738],
#                               [-3.26157, 56.4006],
#                               [-3.25359, 56.40326],
#                               [-3.24583, 56.40707],
#                               [-3.23978, 56.41287],
#                               [-3.23539, 56.41658],
#                               [-3.2274, 56.42118],
#                               [-3.21854, 56.42577],
#                               [-3.18128, 56.44036],
#                               [-3.17637, 56.44269],
#                               [-3.17296, 56.44524],
#                               [-3.16967, 56.44774],
#                               [-3.16621, 56.44964],
#                               [-3.16016, 56.45147],
#                               [-3.15623, 56.45231],
#                               [-3.14911, 56.45426],
#                               [-3.14655, 56.45546],
#                               [-3.14277, 56.45637],
#                               [-3.13846, 56.45669],
#                               [-3.11566, 56.4591],
#                               [-3.09826, 56.46084],
#                               [-3.08939, 56.4619],
#                               [-3.08558, 56.46195],
#                               [-3.07167, 56.46216],
#                               [-3.06537, 56.46347],
#                               [-3.0631, 56.46474],
#                               [-3.06203, 56.46648],
#                               [-3.05937, 56.46962],
#                               [-3.0553, 56.47193],
#                               [-3.04974, 56.47391],
#                               [-3.03825, 56.47696],
#                               [-3.03137, 56.47771],
#                               [-3.02763, 56.47868],
#                               [-3.0238, 56.48027],
#                               [-3.02005, 56.48144],
#                               [-3.01609, 56.48186],
#                               [-3.00506, 56.48159],
#                               [-2.99791, 56.48281],
#                               [-2.98916, 56.48398],
#                               [-2.97544, 56.4832],
#                               [-2.95288, 56.48028],
#                               [-2.94359, 56.47915],
#                               [-2.93916, 56.48113],
#                               [-2.9365, 56.48247],
#                               [-2.93515, 56.48343],
#                               [-2.93456, 56.48351],
#                               [-2.93402, 56.48294],
#                               [-2.93068, 56.48206],
#                               [-2.92139, 56.48154],
#                               [-2.92031, 56.48301],
#                               [-2.91939, 56.48482],
#                               [-2.91862, 56.48564],
#                               [-2.9174, 56.48583],
#                               [-2.9093, 56.4865],
#                               [-2.9042, 56.48775],
#                               [-2.8959, 56.48851],
#                               [-2.89341, 56.48851],
#                               [-2.89235, 56.48834],
#                               [-2.89227, 56.48899],
#                               [-2.88608, 56.49068],
#                               [-2.88121, 56.49398],
#                               [-2.86616, 56.49563],
#                               [-2.86246, 56.49614],
#                               [-2.85888, 56.49797],
#                               [-2.85655, 56.49998],
#                               [-2.85456, 56.50089],
#                               [-2.84925, 56.50334],
#                               [-2.84562, 56.50547],
#                               [-2.84448, 56.50625],
#                               [-2.84168, 56.50711],
#                               [-2.83548, 56.50852],
#                               [-2.83086, 56.50935],
#                               [-2.82114, 56.50943],
#                               [-2.81845, 56.50945],
#                               [-2.81801, 56.50976],
#                               [-2.8186, 56.51026],
#                               [-2.81883, 56.51078],
#                               [-2.81821, 56.5116],
#                               [-2.81726, 56.51379],
#                               [-2.81724, 56.51427],
#                               [-2.81857, 56.51438]],
#               'type': 'LineString'},
#  'properties': {'destination': '56.5142,-2.8189',
#                 'distance': '112 km',
#                 'duration': '1 hour 36 mins',
#                 'origin': '55.9533,-3.1883'},
#  'type': 'Feature'}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4860569d976fe2bfa0c861a4b198fa72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4860569d976fe2bfa0c861a4b198fa72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4860569d976fe2bfa0c861a4b198fa72 = L.map(
#                 &quot;map_4860569d976fe2bfa0c861a4b198fa72&quot;,
#                 {
#                     center: [56.5645, -3.1617],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e9777f4db478c6406f00e810fe75513 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5e9777f4db478c6406f00e810fe75513.addTo(map_4860569d976fe2bfa0c861a4b198fa72);
#
#
#
#         function geo_json_fabc5d239ad88bfe24485ee3dab834e9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_fabc5d239ad88bfe24485ee3dab834e9 = L.geoJson(null, {
#                 onEachFeature: geo_json_fabc5d239ad88bfe24485ee3dab834e9_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_fabc5d239ad88bfe24485ee3dab834e9_add (data) {
#             geo_json_fabc5d239ad88bfe24485ee3dab834e9
#                 .addData(data);
#         }
#             geo_json_fabc5d239ad88bfe24485ee3dab834e9_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[-3.18849, 55.95342], [-3.18763, 55.95433], [-3.18688, 55.95562], [-3.18743, 55.95653], [-3.18928, 55.95802], [-3.19112, 55.95926], [-3.19214, 55.96029], [-3.1953, 55.9618], [-3.19677, 55.96238], [-3.19852, 55.9625], [-3.19964, 55.96265], [-3.20135, 55.96366], [-3.20393, 55.96594], [-3.20869, 55.97088], [-3.20936, 55.9712], [-3.21263, 55.9709], [-3.21838, 55.97027], [-3.23099, 55.96901], [-3.23633, 55.9682], [-3.23757, 55.96705], [-3.23785, 55.96594], [-3.2386, 55.9638], [-3.24033, 55.96239], [-3.24436, 55.96117], [-3.25044, 55.96062], [-3.25865, 55.96088], [-3.26768, 55.96213], [-3.27357, 55.96264], [-3.2789, 55.96246], [-3.29357, 55.96075], [-3.29843, 55.96031], [-3.30396, 55.9606], [-3.31206, 55.96135], [-3.31456, 55.96278], [-3.31808, 55.96541], [-3.32267, 55.96817], [-3.33261, 55.97317], [-3.3395, 55.97622], [-3.3438, 55.97825], [-3.34679, 55.97912], [-3.35056, 55.97958], [-3.36019, 55.97971], [-3.37278, 55.97951], [-3.37805, 55.97918], [-3.38213, 55.9782], [-3.38696, 55.97836], [-3.39467, 55.97905], [-3.40137, 55.98026], [-3.40747, 55.98066], [-3.41367, 55.98076], [-3.41687, 55.98139], [-3.41913, 55.98231], [-3.42092, 55.98345], [-3.42249, 55.98524], [-3.42291, 55.98632], [-3.42283, 55.98829], [-3.42042, 55.99264], [-3.41862, 55.99542], [-3.4158, 55.99995], [-3.41075, 56.00792], [-3.40587, 56.0157], [-3.40562, 56.01854], [-3.40658, 56.02042], [-3.40821, 56.02284], [-3.40843, 56.02423], [-3.40813, 56.02623], [-3.40821, 56.02985], [-3.40897, 56.03432], [-3.40825, 56.03653], [-3.40653, 56.04039], [-3.4053, 56.04339], [-3.40385, 56.04482], [-3.40087, 56.04627], [-3.39397, 56.04882], [-3.39158, 56.05002], [-3.38944, 56.0517], [-3.38787, 56.05407], [-3.38735, 56.06196], [-3.38749, 56.06849], [-3.38861, 56.07169], [-3.38969, 56.07364], [-3.39119, 56.07567], [-3.39562, 56.07981], [-3.39965, 56.08286], [-3.4018, 56.08552], [-3.40253, 56.0884], [-3.40222, 56.09012], [-3.40047, 56.09284], [-3.39478, 56.0974], [-3.39187, 56.09963], [-3.38955, 56.10243], [-3.38888, 56.10451], [-3.38894, 56.10629], [-3.38947, 56.1078], [-3.39301, 56.1129], [-3.39383, 56.11473], [-3.394, 56.11648], [-3.39328, 56.11914], [-3.39186, 56.12263], [-3.39154, 56.1246], [-3.3918, 56.12606], [-3.3943, 56.12992], [-3.39718, 56.13379], [-3.39747, 56.13445], [-3.3979, 56.13735], [-3.3973, 56.1396], [-3.39592, 56.14171], [-3.3935, 56.14511], [-3.39301, 56.14723], [-3.39313, 56.14865], [-3.39397, 56.15062], [-3.39552, 56.15245], [-3.40035, 56.15721], [-3.40259, 56.16119], [-3.4042, 56.16707], [-3.40676, 56.1714], [-3.41037, 56.17544], [-3.41602, 56.18302], [-3.41932, 56.18891], [-3.42113, 56.19225], [-3.42275, 56.19432], [-3.42638, 56.1977], [-3.43289, 56.20319], [-3.4355, 56.20672], [-3.4371, 56.21038], [-3.43773, 56.21476], [-3.43682, 56.21963], [-3.43523, 56.22286], [-3.43395, 56.22468], [-3.43175, 56.22698], [-3.4289, 56.22885], [-3.42488, 56.2305], [-3.41962, 56.23166], [-3.41386, 56.23198], [-3.4094, 56.23215], [-3.40388, 56.23313], [-3.39857, 56.23515], [-3.3947, 56.23741], [-3.38428, 56.24366], [-3.38131, 56.24596], [-3.37918, 56.2483], [-3.37744, 56.25163], [-3.37694, 56.2547], [-3.37739, 56.25807], [-3.37857, 56.26129], [-3.38182, 56.26605], [-3.38418, 56.26835], [-3.3874, 56.27015], [-3.39305, 56.27241], [-3.3964, 56.27469], [-3.39774, 56.27698], [-3.39781, 56.27876], [-3.39731, 56.28096], [-3.39568, 56.28529], [-3.39328, 56.28789], [-3.38982, 56.29025], [-3.3871, 56.29268], [-3.38545, 56.29511], [-3.38467, 56.29752], [-3.38492, 56.30074], [-3.38594, 56.303

# %%
from Google_call import ApiMaps
from nlpProcess import nlpProcess
from make_map import make_map
import folium
import pprint
from deepseekProcess import deepseekProcess

# Data for test
#origin = "55.9533,-3.1883"        # Edinburgh
#destination = "56.5142,-2.8189"
#test_area = ["56.0,-3.0", "56.1,-3.0", "56.1,-2.9", "56.0,-2.9", "56.0,-3.0"]
#tasks = [
#    {"type": "point", "name": "Edinburgh", "coord": origin},
#    {"type": "point", "name": "Newbigging", "coord": destination},
#    {"type": "polyline", "origin":origin, "destination": destination},
#    {"type": "polygon", "name": "Test Area", "coords":test_area}
#]

text1 = """
Edinburgh is Scotland's capital, celebrated globally for its rich history, stunning architecture, and vibrant cultural scene. Situated on a series of hills between the Firth of Forth to the north and the Pentland Hills to the south, it is home to over 500,000 people. Once known for biscuits, brewing, banking, and books, Edinburgh's economy now thrives in finance, science, tourism, and the professions. It is the UK's second-largest financial hub and Europe's fourth-largest. The city also hosts the Scottish Parliament, reaffirming its role as a political center. Edinburgh's retail scene is dominated by Princes Street and major shopping complexes. Its industries include information technology, renewable energy, and life sciences, epitomized by the Edinburgh BioQuarter. Coordinates: 55.9523°N, 3.1882°W..
Dingwall is a historic burgh town in Highland Council Area, located at the head of the Cromarty Firth, 10 miles northwest of Inverness. Its name originates from Scandinavian words meaning 'parliament in the valley.' With royal burgh status since 1226, Dingwall has a rich history as a market center and administrative seat. The town gained prominence in the 18th and 19th centuries due to linen spinning, its status as a road and railway junction, and its role in livestock markets. In the 1970s, the North Sea oil boom further fueled its growth. Dingwall hosts the Highland Traditional Music Festival and Highland Games, with landmarks including Tulloch Castle and St Clement's Church. Coordinates: 57.5957°N, 4.4327°W.

Please tell me how to get to Dingwall from Edinburgh.      
"""
# processor = nlpProcess(text)
# tasks = processor.process()
text2 = """
Newbigging (Near Newtyle, Western Angus)Coordinates: 56.5645°N, 3.1617°WThis small hamlet is close to the western boundary of Angus.It lies half a mile (1 km) northwest of Newtyle, 1¼ miles (2 km) east of Ardler, and 1½ miles (2.5 km) south of Meigle in Perth and Kinross.The surrounding landscape is mostly farmland and rolling countryside, with Newtyle being a historically important village in the region.
Newbigging (Near Monikie, Southeastern Angus)Coordinates: 56.5142°N, 2.8189°WThis village is located 1¼ miles (2 km) south of Monikie and 2 miles (3 km) east-southeast of Wellbank.It grew significantly in the 1950s, when public housing was built, increasing its population.Nearby are the Carlungie and Ardestie souterrains, which are Iron Age underground structures likely used for storage or ritual purposes.Stone quarrying has been an important local industry in the area.
Newbigging (Near Tealing, Southern Angus)Coordinates: 56.5268°N, 2.9395°WThis hamlet is immediately east of the A90 trunk road, one of Scotland’s main north-south highways.It lies half a mile (1 km) southeast of Tealing and 4 miles (6.5 km) north of Dundee.The surrounding area features agriculture, rural homes, and proximity to Dundee’s outskirts.

Tell me about Newbiggings in Angus
"""

# Construct a GPT process object
processor = deepseekProcess(text2)
tasks = processor.extract_features()
print(tasks)

api_key = 'AIzaSyBSKwnMJM1n1qGa0i1SG7G7M3cMqhB6Kqg'

folium_map = make_map(api_key)
folium_map.make_map(tasks)


# Get the full FeatureCollection
#pprint.pprint(folium_map.geojson_all)



# Visualize geojson
#folium.GeoJson(folium_map.geojson_all).add_to(m)




#"""
#Next step: 
#1) Think about how to build RAG and vector database
#2) How to do semantic search through gazetteer database
#3) How the GPT can interpret more complex prompts (eg. related places, events)
# Possible solution: Geo-spatial search & semantic search
#"""
# Out:
# [{'type': 'point', 'name': 'Newbigging (Near Newtyle, Western Angus)', 'description': 'This small hamlet is close to the western boundary of Angus. It lies half a mile (1 km) northwest of Newtyle, 1¼ miles (2 km) east of Ardler, and 1½ miles (2.5 km) south of Meigle in Perth and Kinross. The surrounding landscape is mostly farmland and rolling countryside, with Newtyle being a historically important village in the region.', 'coord': '56.5645,-3.1617'}, {'type': 'point', 'name': 'Newbigging (Near Monikie, Southeastern Angus)', 'description': 'This village is located 1¼ miles (2 km) south of Monikie and 2 miles (3 km) east-southeast of Wellbank. It grew significantly in the 1950s, when public housing was built, increasing its population. Nearby are the Carlungie and Ardestie souterrains, which are Iron Age underground structures likely used for storage or ritual purposes. Stone quarrying has been an important local industry in the area.', 'coord': '56.5142,-2.8189'}, {'type': 'point', 'name': 'Newbigging (Near Tealing, Southern Angus)', 'description': 'This hamlet is immediately east of the A90 trunk road, one of Scotland’s main north-south highways. It lies half a mile (1 km) southeast of Tealing and 4 miles (6.5 km) north of Dundee. The surrounding area features agriculture, rural homes, and proximity to Dundee’s outskirts.', 'coord': '56.5268,-2.9395'}]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9b17e5e2a402c6397458de0e4b66365 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9b17e5e2a402c6397458de0e4b66365&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9b17e5e2a402c6397458de0e4b66365 = L.map(
#                 &quot;map_d9b17e5e2a402c6397458de0e4b66365&quot;,
#                 {
#                     center: [56.5645, -3.1617],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f401e530cbcee82c378c14e35c65916 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f401e530cbcee82c378c14e35c65916.addTo(map_d9b17e5e2a402c6397458de0e4b66365);
#
#
#             var marker_c65f02c3a01e199c0e91d33a18bd2d77 = L.marker(
#                 [56.5645, -3.1617],
#                 {
# }
#             ).addTo(map_d9b17e5e2a402c6397458de0e4b66365);
#
#
#         var popup_052105b3f8d3bfd75954f05bfba4dce5 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_96b7cc8d9a0273074ee2d15d379241a0 = $(`&lt;div id=&quot;html_96b7cc8d9a0273074ee2d15d379241a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Newbigging (Near Newtyle, Western Angus)&lt;/b&gt;&lt;/br&gt;This small hamlet is close to the western boundary of Angus. It lies half a mile (1 km) northwest of Newtyle, 1¼ miles (2 km) east of Ardler, and 1½ miles (2.5 km) south of Meigle in Perth and Kinross. The surrounding landscape is mostly farmland and rolling countryside, with Newtyle being a historically important village in the region.&lt;/div&gt;`)[0];
#                 popup_052105b3f8d3bfd75954f05bfba4dce5.setContent(html_96b7cc8d9a0273074ee2d15d379241a0);
#
#
#
#         marker_c65f02c3a01e199c0e91d33a18bd2d77.bindPopup(popup_052105b3f8d3bfd75954f05bfba4dce5)
#         ;
#
#
#
#
#             marker_c65f02c3a01e199c0e91d33a18bd2d77.bindTooltip(
#                 `&lt;div&gt;
#                      Newbigging (Near Newtyle, Western Angus)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4cdb812786b455aa20112905c4308aa3 = L.marker(
#                 [56.5142, -2.8189],
#                 {
# }
#             ).addTo(map_d9b17e5e2a402c6397458de0e4b66365);
#
#
#         var popup_47ae519108b6920370062309ae11fcf6 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f38663e47a6eb5a3b847051d35994031 = $(`&lt;div id=&quot;html_f38663e47a6eb5a3b847051d35994031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Newbigging (Near Monikie, Southeastern Angus)&lt;/b&gt;&lt;/br&gt;This village is located 1¼ miles (2 km) south of Monikie and 2 miles (3 km) east-southeast of Wellbank. It grew significantly in the 1950s, when public housing was built, increasing its population. Nearby are the Carlungie and Ardestie souterrains, which are Iron Age underground structures likely used for storage or ritual purposes. Stone quarrying has been an important local industry in the area.&lt;/div&gt;`)[0];
#                 popup_47ae519108b6920370062309ae11fcf6.setContent(html_f38663e47a6eb5a3b847051d35994031);
#
#
#
#         marker_4cdb812786b455aa20112905c4308aa3.bindPopup(popup_47ae519108b6920370062309ae11fcf6)
#         ;
#
#
#
#
#             marker_4cdb812786b455aa20112905c4308aa3.bindTooltip(
#                 `&lt;div&gt;
#                      Newbigging (Near Monikie, Southeastern Angus)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_82a9d723297084240c9327c7cba1c367 = L.marker(
#                 [56.5268, -2.9395],
#                 {
# }
#             ).addTo(map_d9b17e5e2a402c6397458de0e4b66365);
#
#
#         var popup_01a8ea661c719fa05df78aa0ec8f2a97 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_3a817c84e6f91aab3387cf70d5cba910 = $(`&lt;div id=&quot;html_3a817c84e6f91aab3387cf70d5cba910&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Newbigging (Near Tealing, Southern Angus)&lt;/b&gt;&lt;/br&gt;This hamlet is immediately east of the A90 trunk road, one of Scotland’s main north-south highways. It lies half a mile (1 km) southeast of Tealing and 4 miles (6.5 km) north of Dundee. The surrounding area features agriculture, rural homes, and proximity to Dundee’s outskirts.&lt;/div&gt;`)[0];
#                 popup_01a8ea661c719fa05df78aa0ec8f2a97.setContent(html_3a817c84e6f91aab3387cf70d5cba910);
#
#
#
#         marker_82a9d723297084240c9327c7cba1c367.bindPopup(popup_01a8ea661c719fa05df78aa0ec8f2a97)
#         ;
#
#
#
#
#             marker_82a9d723297084240c9327c7cba
