# %%
from Google_call import ApiMaps
import folium
import pprint

origin = "55.9533,-3.1883"        # Edinburgh
destination = "56.5142,-2.8189"

 
map = ApiMaps()
geojson_route = map.draw_polyline(origin,destination)
# print GeoJSON 

pprint.pprint(geojson_route)

# 地图中心取起点
m = folium.Map(location=[origin], zoom_start=10)

# 添加路线
folium.GeoJson(geojson_route, name="Route").add_to(m)
m
# Out:
# {'geometry': {'coordinates': [[-3.18849, 55.95342],
#                               [-3.18763, 55.95433],
#                               [-3.18688, 55.95562],
#                               [-3.18743, 55.95653],
#                               [-3.18928, 55.95802],
#                               [-3.19112, 55.95926],
#                               [-3.19214, 55.96029],
#                               [-3.1953, 55.9618],
#                               [-3.19677, 55.96238],
#                               [-3.19852, 55.9625],
#                               [-3.20135, 55.96366],
#                               [-3.20393, 55.96594],
#                               [-3.20869, 55.97088],
#                               [-3.20936, 55.9712],
#                               [-3.21263, 55.9709],
#                               [-3.21838, 55.97027],
#                               [-3.23099, 55.96901],
#                               [-3.23633, 55.9682],
#                               [-3.23757, 55.96705],
#                               [-3.23785, 55.96594],
#                               [-3.2386, 55.9638],
#                               [-3.24033, 55.96239],
#                               [-3.24436, 55.96117],
#                               [-3.25044, 55.96062],
#                               [-3.25865, 55.96088],
#                               [-3.26768, 55.96213],
#                               [-3.27357, 55.96264],
#                               [-3.2789, 55.96246],
#                               [-3.29357, 55.96075],
#                               [-3.29843, 55.96031],
#                               [-3.30396, 55.9606],
#                               [-3.31206, 55.96135],
#                               [-3.31456, 55.96278],
#                               [-3.31808, 55.96541],
#                               [-3.32267, 55.96817],
#                               [-3.33261, 55.97317],
#                               [-3.3395, 55.97622],
#                               [-3.3438, 55.97825],
#                               [-3.34679, 55.97912],
#                               [-3.35056, 55.97958],
#                               [-3.36019, 55.97971],
#                               [-3.37278, 55.97951],
#                               [-3.37805, 55.97918],
#                               [-3.38213, 55.9782],
#                               [-3.38696, 55.97836],
#                               [-3.39467, 55.97905],
#                               [-3.40137, 55.98026],
#                               [-3.40747, 55.98066],
#                               [-3.41367, 55.98076],
#                               [-3.41687, 55.98139],
#                               [-3.41913, 55.98231],
#                               [-3.42092, 55.98345],
#                               [-3.42249, 55.98524],
#                               [-3.42291, 55.98632],
#                               [-3.42283, 55.98829],
#                               [-3.41862, 55.99542],
#                               [-3.4158, 55.99995],
#                               [-3.41075, 56.00792],
#                               [-3.40587, 56.0157],
#                               [-3.40562, 56.01854],
#                               [-3.40658, 56.02042],
#                               [-3.40821, 56.02284],
#                               [-3.40813, 56.02623],
#                               [-3.40821, 56.02985],
#                               [-3.40897, 56.03432],
#                               [-3.40825, 56.03653],
#                               [-3.40653, 56.04039],
#                               [-3.4053, 56.04339],
#                               [-3.40385, 56.04482],
#                               [-3.40087, 56.04627],
#                               [-3.39397, 56.04882],
#                               [-3.39158, 56.05002],
#                               [-3.38944, 56.0517],
#                               [-3.38787, 56.05407],
#                               [-3.38735, 56.06196],
#                               [-3.38749, 56.06849],
#                               [-3.38969, 56.07364],
#                               [-3.39119, 56.07567],
#                               [-3.39562, 56.07981],
#                               [-3.39965, 56.08286],
#                               [-3.4018, 56.08552],
#                               [-3.40253, 56.0884],
#                               [-3.40222, 56.09012],
#                               [-3.40047, 56.09284],
#                               [-3.39478, 56.0974],
#                               [-3.39187, 56.09963],
#                               [-3.38955, 56.10243],
#                               [-3.38888, 56.10451],
#                               [-3.38947, 56.1078],
#                               [-3.39301, 56.1129],
#                               [-3.39383, 56.11473],
#                               [-3.394, 56.11648],
#                               [-3.39328, 56.11914],
#                               [-3.39186, 56.12263],
#                               [-3.39154, 56.1246],
#                               [-3.3918, 56.12606],
#                               [-3.3943, 56.12992],
#                               [-3.39718, 56.13379],
#                               [-3.39747, 56.13445],
#                               [-3.3979, 56.13735],
#                               [-3.3973, 56.1396],
#                               [-3.39592, 56.14171],
#                               [-3.3935, 56.14511],
#                               [-3.39301, 56.14723],
#                               [-3.39313, 56.14865],
#                               [-3.39397, 56.15062],
#                               [-3.39552, 56.15245],
#                               [-3.40035, 56.15721],
#                               [-3.40259, 56.16119],
#                               [-3.4042, 56.16707],
#                               [-3.40676, 56.1714],
#                               [-3.41037, 56.17544],
#                               [-3.41602, 56.18302],
#                               [-3.41932, 56.18891],
#                               [-3.42113, 56.19225],
#                               [-3.42275, 56.19432],
#                               [-3.42638, 56.1977],
#                               [-3.43289, 56.20319],
#                               [-3.4355, 56.20672],
#                               [-3.4371, 56.21038],
#                               [-3.43773, 56.21476],
#                               [-3.43682, 56.21963],
#                               [-3.43395, 56.22468],
#                               [-3.43175, 56.22698],
#                               [-3.4289, 56.22885],
#                               [-3.42488, 56.2305],
#                               [-3.41962, 56.23166],
#                               [-3.41386, 56.23198],
#                               [-3.4094, 56.23215],
#                               [-3.40388, 56.23313],
#                               [-3.39857, 56.23515],
#                               [-3.3947, 56.23741],
#                               [-3.38428, 56.24366],
#                               [-3.38131, 56.24596],
#                               [-3.37918, 56.2483],
#                               [-3.37744, 56.25163],
#                               [-3.37694, 56.2547],
#                               [-3.37739, 56.25807],
#                               [-3.37857, 56.26129],
#                               [-3.38182, 56.26605],
#                               [-3.38418, 56.26835],
#                               [-3.3874, 56.27015],
#                               [-3.39305, 56.27241],
#                               [-3.3964, 56.27469],
#                               [-3.39774, 56.27698],
#                               [-3.39781, 56.27876],
#                               [-3.39731, 56.28096],
#                               [-3.39568, 56.28529],
#                               [-3.39328, 56.28789],
#                               [-3.38982, 56.29025],
#                               [-3.3871, 56.29268],
#                               [-3.38545, 56.29511],
#                               [-3.38467, 56.29752],
#                               [-3.38491, 56.3007],
#                               [-3.38592, 56.30358],
#                               [-3.38591, 56.30543],
#                               [-3.38425, 56.30798],
#                               [-3.37935, 56.31061],
#                               [-3.37397, 56.31274],
#                               [-3.37229, 56.31425],
#                               [-3.37188, 56.31568],
#                               [-3.37308, 56.31783],
#                               [-3.37516, 56.31899],
#                               [-3.37943, 56.31977],
#                               [-3.38693, 56.32033],
#                               [-3.39281, 56.32194],
#                               [-3.39576, 56.32357],
#                               [-3.3973, 56.32515],
#                               [-3.3994, 56.32869],
#                               [-3.40012, 56.33212],
#                               [-3.39992, 56.33464],
#                               [-3.39896, 56.33759],
#                               [-3.39783, 56.34087],
#                               [-3.39695, 56.34539],
#                               [-3.39712, 56.3492],
#                               [-3.39914, 56.35293],
#                               [-3.40306, 56.35683],
#                               [-3.40748, 56.35954],
#                               [-3.41154, 56.36128],
#                               [-3.4177, 56.36305],
#                               [-3.42085, 56.36419],
#                               [-3.42297, 56.36615],
#                               [-3.4234, 56.36803],
#                               [-3.42252, 56.37031],
#                               [-3.41939, 56.37268],
#                               [-3.41525, 56.3742],
#                               [-3.41281, 56.37534],
#                               [-3.4111, 56.37681],
#                               [-3.40658, 56.38266],
#                               [-3.40418, 56.38504],
#                               [-3.39971, 56.38645],
#                               [-3.38763, 56.38677],
#                               [-3.38311, 56.38628],
#                               [-3.37847, 56.38524],
#                               [-3.37329, 56.38337],
#                               [-3.36903, 56.38286],
#                               [-3.35299, 56.38228],
#                               [-3.34719, 56.38032],
#                               [-3.34207, 56.37807],
#                               [-3.33622, 56.37533],
#                               [-3.3321, 56.37412],
#                               [-3.32555, 56.3738],
#                               [-3.32123, 56.37393],
#                               [-3.3152, 56.37441],
#                               [-3.30908, 56.37599],
#                               [-3.3008, 56.38025],
#                               [-3.29211, 56.38427],
#                               [-3.27843, 56.39015],
#                               [-3.27458, 56.39258],
#                               [-3.27275, 56.39476],
#                               [-3.27009, 56.39663],
#                               [-3.26287, 56.40005],
#                               [-3.25501, 56.40269],
#                               [-3.24628, 56.40676],
#                               [-3.2409, 56.41177],
#                               [-3.23588, 56.41628],
#                               [-3.22966, 56.41988],
#                               [-3.21912, 56.42553],
#                               [-3.18262, 56.43984],
#                               [-3.17676, 56.44245],
#                               [-3.17379, 56.44459],
#                               [-3.17015, 56.4474],
#                               [-3.16693, 56.44932],
#                               [-3.16133, 56.45121],
#                               [-3.1572, 56.45211],
#                               [-3.14955, 56.45406],
#                               [-3.14467, 56.45603],
#                               [-3.13905, 56.45666],
#                               [-3.11833, 56.45885],
#                               [-3.10101, 56.46049],
#                               [-3.08616, 56.46196],
#                               [-3.0726, 56.46211],
#                               [-3.06668, 56.46305],
#                               [-3.06385, 56.4641],
#                               [-3.06309, 56.46471],
#                               [-3.06296, 56.46493],
#                               [-3.06217, 56.46619],
#                               [-3.06076, 56.46827],
#                               [-3.05812, 56.47052],
#                               [-3.05658, 56.47139],
#                               [-3.05096, 56.47342],
#                               [-3.04987, 56.47393],
#                               [-3.03871, 56.47687],
#                               [-3.03204, 56.47763],
#                               [-3.02835, 56.4784],
#                               [-3.02443, 56.48003],
#                               [-3.02042, 56.48134],
#                               [-3.01663, 56.48186],
#                               [-3.00689, 56.4815],
#                               [-2.99915, 56.48258],
#                               [-2.9892, 56.48394],
#                               [-2.97549, 56.48319],
#                               [-2.95376, 56.48038],
#                               [-2.94383, 56.47913],
#                               [-2.94193, 56.47976],
#                               [-2.93514, 56.48332],
#                               [-2.93482, 56.48356],
#                               [-2.93452, 56.48329],
#                               [-2.93276, 56.48242],
#                               [-2.93127, 56.48213],
#                               [-2.92913, 56.48204],
#                               [-2.92145, 56.4815],
#                               [-2.92046, 56.48273],
#                               [-2.91957, 56.48448],
#                               [-2.91897, 56.48541],
#                               [-2.9179, 56.4858],
#                               [-2.91012, 56.48631],
#                               [-2.90533, 56.48751],
#                               [-2.8985, 56.48842],
#                               [-2.89412, 56.48853],
#                               [-2.89257, 56.48838],
#                               [-2.8922, 56.48857],
#                               [-2.89211, 56.48904],
#                               [-2.88984, 56.48956],
#                               [-2.8866, 56.49036],
#                               [-2.88219, 56.49333],
#                               [-2.8811, 56.49402],
#                               [-2.87953, 56.49418],
#                               [-2.87296, 56.49483],
#                               [-2.86816, 56.49534],
#                               [-2.86342, 56.496],
#                               [-2.85997, 56.49718],
#                               [-2.85634, 56.50014],
#                               [-2.85074, 56.50265],
#                               [-2.84627, 56.50488],
#                               [-2.84536, 56.50573],
#                               [-2.84308, 56.50668],
#                               [-2.83663, 56.50828],
#                               [-2.83187, 56.50923],
#                               [-2.82651, 56.5094],
#                               [-2.81853, 56.50944],
#                               [-2.818, 56.50974],
#                               [-2.81826, 56.50996],
#                               [-2.81883, 56.51052],
#                               [-2.81872, 56.51094],
#                               [-2.81748, 56.51284],
#                               [-2.81724, 56.51419],
#                               [-2.81857, 56.51438]],
#               'type': 'LineString'},
#  'properties': {'destination': '56.5142,-2.8189',
#                 'distance': '112 km',
#                 'duration': '1 hour 35 mins',
#                 'origin': '55.9533,-3.1883'},
#  'type': 'Feature'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      13 pprint.pprint(geojson_route)
#      15 # 地图中心取起点
# ---> 16 m = folium.Map(location=[origin], zoom_start=10)
#      18 # 添加路线
#      19 folium.GeoJson(geojson_route, name="Route").add_to(m)
#
# File e:\GfS-RAG-Map-Return\.conda\Lib\site-packages\folium\folium.py:277, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, font_size, **kwargs)
#     275     zoom_start = 1
#     276 else:
# --> 277     self.location = validate_location(location)
#     279 Figure().add_child(self)
#     281 # Map Size Parameters.
#
# File e:\GfS-RAG-Map-Return\.conda\Lib\site-packages\folium\utilities.py:88, in validate_location(location)
#      82     raise TypeError(
#      83         "Location should be a sized variable, "
#      84         "for example a list or a tuple, instead got "
#      85         f"{location!r} of type {type(location)}."
#      86     )
#      87 if len(location) != 2:
# ---> 88     raise ValueError(
#      89         "Expected two (lat, lon) values for location, "
#      90         f"instead got: {location!r}."
#      91     )
#      92 try:
#      93     coords = (location[0], location[1])
#
# ValueError: Expected two (lat, lon) values for location, instead got: ['55.9533,-3.1883'].

# %%
from Google_call import ApiMaps
from nlpProcess import nlpProcess
from make_map import make_map
import folium
import pprint
from deepseekProcess import deepseekProcess

# Data for test
#origin = "55.9533,-3.1883"        # Edinburgh
#destination = "56.5142,-2.8189"
#test_area = ["56.0,-3.0", "56.1,-3.0", "56.1,-2.9", "56.0,-2.9", "56.0,-3.0"]
#tasks = [
#    {"type": "point", "name": "Edinburgh", "coord": origin},
#    {"type": "point", "name": "Newbigging", "coord": destination},
#    {"type": "polyline", "origin":origin, "destination": destination},
#    {"type": "polygon", "name": "Test Area", "coords":test_area}
#]

text1 = """
Edinburgh is Scotland's capital, celebrated globally for its rich history, stunning architecture, and vibrant cultural scene. Situated on a series of hills between the Firth of Forth to the north and the Pentland Hills to the south, it is home to over 500,000 people. Once known for biscuits, brewing, banking, and books, Edinburgh's economy now thrives in finance, science, tourism, and the professions. It is the UK's second-largest financial hub and Europe's fourth-largest. The city also hosts the Scottish Parliament, reaffirming its role as a political center. Edinburgh's retail scene is dominated by Princes Street and major shopping complexes. Its industries include information technology, renewable energy, and life sciences, epitomized by the Edinburgh BioQuarter. Coordinates: 55.9523°N, 3.1882°W..
Dingwall is a historic burgh town in Highland Council Area, located at the head of the Cromarty Firth, 10 miles northwest of Inverness. Its name originates from Scandinavian words meaning 'parliament in the valley.' With royal burgh status since 1226, Dingwall has a rich history as a market center and administrative seat. The town gained prominence in the 18th and 19th centuries due to linen spinning, its status as a road and railway junction, and its role in livestock markets. In the 1970s, the North Sea oil boom further fueled its growth. Dingwall hosts the Highland Traditional Music Festival and Highland Games, with landmarks including Tulloch Castle and St Clement's Church. Coordinates: 57.5957°N, 4.4327°W.

Please tell me how to get to Dingwall from Edinburgh.      
"""
# processor = nlpProcess(text)
# tasks = processor.process()
text2 = """
Newbigging (Near Newtyle, Western Angus)Coordinates: 56.5645°N, 3.1617°WThis small hamlet is close to the western boundary of Angus.It lies half a mile (1 km) northwest of Newtyle, 1¼ miles (2 km) east of Ardler, and 1½ miles (2.5 km) south of Meigle in Perth and Kinross.The surrounding landscape is mostly farmland and rolling countryside, with Newtyle being a historically important village in the region.
Newbigging (Near Monikie, Southeastern Angus)Coordinates: 56.5142°N, 2.8189°WThis village is located 1¼ miles (2 km) south of Monikie and 2 miles (3 km) east-southeast of Wellbank.It grew significantly in the 1950s, when public housing was built, increasing its population.Nearby are the Carlungie and Ardestie souterrains, which are Iron Age underground structures likely used for storage or ritual purposes.Stone quarrying has been an important local industry in the area.
Newbigging (Near Tealing, Southern Angus)Coordinates: 56.5268°N, 2.9395°WThis hamlet is immediately east of the A90 trunk road, one of Scotland’s main north-south highways.It lies half a mile (1 km) southeast of Tealing and 4 miles (6.5 km) north of Dundee.The surrounding area features agriculture, rural homes, and proximity to Dundee’s outskirts.

Tell me about Newbiggings in Angus
"""

# Construct a GPT process object
processor = deepseekProcess(text2)
tasks = processor.extract_features()
print(tasks)



folium_map = make_map()
folium_map.make_map(tasks)


# Get the full FeatureCollection
#pprint.pprint(folium_map.geojson_all)



# Visualize geojson
#folium.GeoJson(folium_map.geojson_all).add_to(m)




#"""
#Next step: 
#1) Think about how to build RAG and vector database
#2) How to do semantic search through gazetteer database
#3) How the GPT can interpret more complex prompts (eg. related places, events)
# Possible solution: Geo-spatial search & semantic search
#"""
# Out:
# [{'type': 'point', 'name': 'Newbigging (Near Newtyle, Western Angus)', 'description': 'This small hamlet is close to the western boundary of Angus. It lies half a mile (1 km) northwest of Newtyle, 1¼ miles (2 km) east of Ardler, and 1½ miles (2.5 km) south of Meigle in Perth and Kinross. The surrounding landscape is mostly farmland and rolling countryside, with Newtyle being a historically important village in the region.', 'coord': '56.5645,-3.1617'}, {'type': 'point', 'name': 'Newbigging (Near Monikie, Southeastern Angus)', 'description': 'This village is located 1¼ miles (2 km) south of Monikie and 2 miles (3 km) east-southeast of Wellbank. It grew significantly in the 1950s, when public housing was built, increasing its population. Nearby are the Carlungie and Ardestie souterrains, which are Iron Age underground structures likely used for storage or ritual purposes. Stone quarrying has been an important local industry in the area.', 'coord': '56.5142,-2.8189'}, {'type': 'point', 'name': 'Newbigging (Near Tealing, Southern Angus)', 'description': 'This hamlet is immediately east of the A90 trunk road, one of Scotland’s main north-south highways. It lies half a mile (1 km) southeast of Tealing and 4 miles (6.5 km) north of Dundee. The surrounding area features agriculture, rural homes, and proximity to Dundee’s outskirts.', 'coord': '56.5268,-2.9395'}]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_044e5c4abf8861ed62599532da32b3e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_044e5c4abf8861ed62599532da32b3e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_044e5c4abf8861ed62599532da32b3e9 = L.map(
#                 &quot;map_044e5c4abf8861ed62599532da32b3e9&quot;,
#                 {
#                     center: [56.5645, -3.1617],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_104cafce5b9d4912c0bc8eda4d7645d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_104cafce5b9d4912c0bc8eda4d7645d6.addTo(map_044e5c4abf8861ed62599532da32b3e9);
#
#
#             var marker_31785e7c590b2913b44e9ce8e8a74054 = L.marker(
#                 [56.5645, -3.1617],
#                 {
# }
#             ).addTo(map_044e5c4abf8861ed62599532da32b3e9);
#
#
#         var popup_9a2746f7f7580f145056d5bda729bbcd = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_1372bf7c7aff549f560e6f7a407cfd68 = $(`&lt;div id=&quot;html_1372bf7c7aff549f560e6f7a407cfd68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Newbigging (Near Newtyle, Western Angus)&lt;/b&gt;&lt;/br&gt;This small hamlet is close to the western boundary of Angus. It lies half a mile (1 km) northwest of Newtyle, 1¼ miles (2 km) east of Ardler, and 1½ miles (2.5 km) south of Meigle in Perth and Kinross. The surrounding landscape is mostly farmland and rolling countryside, with Newtyle being a historically important village in the region.&lt;/div&gt;`)[0];
#                 popup_9a2746f7f7580f145056d5bda729bbcd.setContent(html_1372bf7c7aff549f560e6f7a407cfd68);
#
#
#
#         marker_31785e7c590b2913b44e9ce8e8a74054.bindPopup(popup_9a2746f7f7580f145056d5bda729bbcd)
#         ;
#
#
#
#
#             marker_31785e7c590b2913b44e9ce8e8a74054.bindTooltip(
#                 `&lt;div&gt;
#                      Newbigging (Near Newtyle, Western Angus)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_748b64115efc216ae278eb53638d2632 = L.marker(
#                 [56.5142, -2.8189],
#                 {
# }
#             ).addTo(map_044e5c4abf8861ed62599532da32b3e9);
#
#
#         var popup_216a8a931281a2fc565d9487047178f2 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_ba5c48404bff1b71a4c2c6e0e4f831fc = $(`&lt;div id=&quot;html_ba5c48404bff1b71a4c2c6e0e4f831fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Newbigging (Near Monikie, Southeastern Angus)&lt;/b&gt;&lt;/br&gt;This village is located 1¼ miles (2 km) south of Monikie and 2 miles (3 km) east-southeast of Wellbank. It grew significantly in the 1950s, when public housing was built, increasing its population. Nearby are the Carlungie and Ardestie souterrains, which are Iron Age underground structures likely used for storage or ritual purposes. Stone quarrying has been an important local industry in the area.&lt;/div&gt;`)[0];
#                 popup_216a8a931281a2fc565d9487047178f2.setContent(html_ba5c48404bff1b71a4c2c6e0e4f831fc);
#
#
#
#         marker_748b64115efc216ae278eb53638d2632.bindPopup(popup_216a8a931281a2fc565d9487047178f2)
#         ;
#
#
#
#
#             marker_748b64115efc216ae278eb53638d2632.bindTooltip(
#                 `&lt;div&gt;
#                      Newbigging (Near Monikie, Southeastern Angus)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_15e8db73d93337574904f5c6b089daa3 = L.marker(
#                 [56.5268, -2.9395],
#                 {
# }
#             ).addTo(map_044e5c4abf8861ed62599532da32b3e9);
#
#
#         var popup_109cccb3e0942e59c98ae2c0a79f38e4 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_1f99466bc0a8dc91abee480a4941850e = $(`&lt;div id=&quot;html_1f99466bc0a8dc91abee480a4941850e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Newbigging (Near Tealing, Southern Angus)&lt;/b&gt;&lt;/br&gt;This hamlet is immediately east of the A90 trunk road, one of Scotland’s main north-south highways. It lies half a mile (1 km) southeast of Tealing and 4 miles (6.5 km) north of Dundee. The surrounding area features agriculture, rural homes, and proximity to Dundee’s outskirts.&lt;/div&gt;`)[0];
#                 popup_109cccb3e0942e59c98ae2c0a79f38e4.setContent(html_1f99466bc0a8dc91abee480a4941850e);
#
#
#
#         marker_15e8db73d93337574904f5c6b089daa3.bindPopup(popup_109cccb3e0942e59c98ae2c0a79f38e4)
#         ;
#
#
#
#
#             marker_15e8db73d93337574904f5c6b08
